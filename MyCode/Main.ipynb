# %% [markdown]
# # Import Libraries

# %%
import warnings
#pip install scikit-learn
warnings.filterwarnings('ignore')
#%pip install lazypredict
import pandas as pd
import numpy as np
import math
import pylab as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
# %matplotlib inline


from sklearn.ensemble import RandomForestRegressor as Rfr    # el modelo , el alias es cosa mia
from sklearn.model_selection import train_test_split as tts  # el alias es cosa mia
from sklearn.datasets import load_boston   # dataset

# %% [markdown]
# ## Import dataframes

# %%
salaries = pd.read_csv(r'''C:\Users\pombo\OneDrive\Escritorio\Ironhack\Labs\Day35Proy\w6-Kaggle-Competition-Machine-Learning\data\salaries_data.csv''')

test = pd.read_csv(r'''C:\Users\pombo\OneDrive\Escritorio\Ironhack\Labs\Day35Proy\w6-Kaggle-Competition-Machine-Learning\data\testeo.csv''')

muestra = pd.read_csv(r'''C:\Users\pombo\OneDrive\Escritorio\Ironhack\Labs\Day35Proy\w6-Kaggle-Competition-Machine-Learning\data\muestra.csv''')

# %% [markdown]
# ## Take a look at dataframe

# %%
salaries.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L

# %%
salaries.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
salaries.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L

# %%
test.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#    salary salary_currency employee_residence  remote_ratio company_location  \
# 0  260000             USD                 JP             0               JP
# 1   87000             USD                 US           100               US
# 2   85000             USD                 US           100               US
# 3  299000             CNY                 CN             0               CN
# 4  450000             INR                 IN           100               IN
#
#   company_size
# 0            S
# 1            L
# 2            L
# 3            M
# 4            L

# %%
salaries.experience_level.value_counts()
# Out:
# SE    243
# MI    172
# EN     65
# EX     20
# Name: experience_level, dtype: int64

# %%
salaries.job_title.value_counts()
# Out:
# Data Scientist                              121
# Data Engineer                               111
# Data Analyst                                 81
# Machine Learning Engineer                    31
# Research Scientist                           12
# Data Science Manager                         12
# Data Architect                                8
# Machine Learning Scientist                    7
# Data Analytics Manager                        7
# Big Data Engineer                             7
# Director of Data Science                      7
# ML Engineer                                   6
# Lead Data Engineer                            6
# Principal Data Scientist                      6
# Applied Data Scientist                        5
# Data Engineering Manager                      5
# Data Science Consultant                       5
# AI Scientist                                  5
# BI Data Analyst                               5
# Head of Data                                  4
# Business Data Analyst                         4
# Computer Vision Engineer                      4
# Analytics Engineer                            3
# Lead Data Scientist                           3
# Applied Machine Learning Scientist            3
# Cloud Data Engineer                           2
# Machine Learning Infrastructure Engineer      2
# Lead Data Analyst                             2
# Data Analytics Engineer                       2
# Director of Data Engineering                  2
# ETL Developer                                 2
# Head of Data Science                          2
# Machine Learning Developer                    2
# Data Science Engineer                         2
# Machine Learning Manager                      1
# Staff Data Scientist                          1
# Head of Machine Learning                      1
# Finance Data Analyst                          1
# Financial Data Analyst                        1
# Data Analytics Lead                           1
# 3D Computer Vision Researcher                 1
# Principal Data Analyst                        1
# Product Data Analyst                          1
# Big Data Architect                            1
# Data Specialist                               1
# Lead Machine Learning Engineer                1
# Marketing Data Analyst                        1
# Computer Vision Software Engineer             1
# Name: job_title, dtype: int64

# %%
job_salaries = list(salaries.job_title.unique())
job_salaries.sort()
job_salaries
# Out:
# ['3D Computer Vision Researcher',
#  'AI Scientist',
#  'Analytics Engineer',
#  'Applied Data Scientist',
#  'Applied Machine Learning Scientist',
#  'BI Data Analyst',
#  'Big Data Architect',
#  'Big Data Engineer',
#  'Business Data Analyst',
#  'Cloud Data Engineer',
#  'Computer Vision Engineer',
#  'Computer Vision Software Engineer',
#  'Data Analyst',
#  'Data Analytics Engineer',
#  'Data Analytics Lead',
#  'Data Analytics Manager',
#  'Data Architect',
#  'Data Engineer',
#  'Data Engineering Manager',
#  'Data Science Consultant',
#  'Data Science Engineer',
#  'Data Science Manager',
#  'Data Scientist',
#  'Data Specialist',
#  'Director of Data Engineering',
#  'Director of Data Science',
#  'ETL Developer',
#  'Finance Data Analyst',
#  'Financial Data Analyst',
#  'Head of Data',
#  'Head of Data Science',
#  'Head of Machine Learning',
#  'Lead Data Analyst',
#  'Lead Data Engineer',
#  'Lead Data Scientist',
#  'Lead Machine Learning Engineer',
#  'ML Engineer',
#  'Machine Learning Developer',
#  'Machine Learning Engineer',
#  'Machine Learning Infrastructure Engineer',
#  'Machine Learning Manager',
#  'Machine Learning Scientist',
#  'Marketing Data Analyst',
#  'Principal Data Analyst',
#  'Principal Data Scientist',
#  'Product Data Analyst',
#  'Research Scientist',
#  'Staff Data Scientist']

# %%
job_test = list(test.job_title.unique())
job_test.sort()
job_test
# Out:
# ['AI Scientist',
#  'Analytics Engineer',
#  'Applied Machine Learning Scientist',
#  'BI Data Analyst',
#  'Big Data Engineer',
#  'Business Data Analyst',
#  'Computer Vision Engineer',
#  'Computer Vision Software Engineer',
#  'Data Analyst',
#  'Data Analytics Engineer',
#  'Data Architect',
#  'Data Engineer',
#  'Data Science Consultant',
#  'Data Science Engineer',
#  'Data Scientist',
#  'Financial Data Analyst',
#  'Head of Data',
#  'Head of Data Science',
#  'Lead Data Analyst',
#  'Machine Learning Developer',
#  'Machine Learning Engineer',
#  'Machine Learning Infrastructure Engineer',
#  'Machine Learning Scientist',
#  'NLP Engineer',
#  'Principal Data Analyst',
#  'Principal Data Engineer',
#  'Principal Data Scientist',
#  'Product Data Analyst',
#  'Research Scientist']

# %%
not_test = []
not_salaries = []

for i in job_salaries:
    if i not in job_test:
        not_test.append(i)
for j in job_test:
    if i not in job_salaries:
        not_salaries.append(i)        
        
        
not_test.sort()
not_test
# Out:
# ['3D Computer Vision Researcher',
#  'Applied Data Scientist',
#  'Big Data Architect',
#  'Cloud Data Engineer',
#  'Data Analytics Lead',
#  'Data Analytics Manager',
#  'Data Engineering Manager',
#  'Data Science Manager',
#  'Data Specialist',
#  'Director of Data Engineering',
#  'Director of Data Science',
#  'ETL Developer',
#  'Finance Data Analyst',
#  'Head of Machine Learning',
#  'Lead Data Engineer',
#  'Lead Data Scientist',
#  'Lead Machine Learning Engineer',
#  'ML Engineer',
#  'Machine Learning Manager',
#  'Marketing Data Analyst',
#  'Staff Data Scientist']

# %%
salaries.company_location.value_counts()
# Out:
# US    296
# GB     41
# CA     25
# DE     23
# IN     19
# FR     12
# ES     12
# GR     10
# JP      4
# NL      4
# PT      4
# LU      3
# AE      3
# AT      3
# PL      3
# PK      3
# TR      3
# CH      2
# AU      2
# BR      2
# NG      2
# SI      2
# BE      2
# MT      1
# IR      1
# DZ      1
# HU      1
# CZ      1
# HN      1
# RO      1
# CL      1
# EE      1
# UA      1
# NZ      1
# DK      1
# CN      1
# KE      1
# VN      1
# MX      1
# IE      1
# AS      1
# MD      1
# SG      1
# Name: company_location, dtype: int64

# %%
salaries[salaries.job_title == 'Data Scientist'].sort_values(by=['salary_in_usd'])
# Out:
#      work_year experience_level employment_type       job_title  salary  \
# 51        2021               MI              FT  Data Scientist   58000
# 58        2021               EN              FT  Data Scientist    4000
# 409       2021               MI              FT  Data Scientist  420000
# 437       2021               MI              FT  Data Scientist  700000
# 142       2021               EN              FT  Data Scientist   13400
# ..         ...              ...             ...             ...     ...
# 49        2022               SE              FT  Data Scientist  215300
# 203       2022               SE              FT  Data Scientist  220000
# 184       2022               SE              FT  Data Scientist  230000
# 384       2022               SE              FT  Data Scientist  260000
# 63        2020               SE              FT  Data Scientist  412000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 51              MXN           2859                 MX             0
# 58              USD           4000                 VN             0
# 409             INR           5679                 IN           100
# 437             INR           9466                 IN             0
# 142             USD          13400                 UA           100
# ..              ...            ...                ...           ...
# 49              USD         215300                 US           100
# 203             USD         220000                 US           100
# 184             USD         230000                 US           100
# 384             USD         260000                 US           100
# 63              USD         412000                 US           100
#
#     company_location company_size
# 51                MX            S
# 58                VN            M
# 409               US            S
# 437               IN            S
# 142               UA            L
# ..               ...          ...
# 49                US            L
# 203               US            M
# 184               US            M
# 384               US            M
# 63                US            L
#
# [121 rows x 11 columns]

# %%
salaries[salaries.job_title == 'Data Scientist']
# Out:
#      work_year experience_level employment_type       job_title  salary  \
# 6         2020               EN              FT  Data Scientist   45000
# 7         2021               EN              FT  Data Scientist   42000
# 10        2020               MI              FT  Data Scientist   55000
# 23        2021               MI              FT  Data Scientist  160000
# 27        2021               MI              FT  Data Scientist  130000
# ..         ...              ...             ...             ...     ...
# 485       2021               MI              FT  Data Scientist   76760
# 488       2022               SE              FT  Data Scientist  140000
# 489       2022               MI              FT  Data Scientist  102100
# 492       2021               SE              FT  Data Scientist  110000
# 494       2022               SE              FT  Data Scientist  144000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 6               EUR          51321                 FR             0
# 7               EUR          49646                 FR            50
# 10              EUR          62726                 FR            50
# 23              USD         160000                 US           100
# 27              USD         130000                 US            50
# ..              ...            ...                ...           ...
# 485             EUR          90734                 DE            50
# 488             USD         140000                 US           100
# 489             USD         102100                 US             0
# 492             CAD          87738                 CA           100
# 494             USD         144000                 US           100
#
#     company_location company_size
# 6                 FR            S
# 7                 FR            M
# 10                LU            S
# 23                US            L
# 27                US            L
# ..               ...          ...
# 485               DE            L
# 488               US            M
# 489               US            M
# 492               CA            S
# 494               US            M
#
# [121 rows x 11 columns]

# %%
test[test.job_title == 'Data Scientist']
# Out:
#      work_year experience_level employment_type       job_title   salary  \
# 6         2020               SE              FT  Data Scientist    60000
# 8         2020               MI              FT  Data Scientist    45760
# 11        2020               SE              FT  Data Scientist   120000
# 13        2020               EN              PT  Data Scientist    19000
# 15        2020               MI              FT  Data Scientist    37000
# 26        2021               EN              FT  Data Scientist   100000
# 28        2021               MI              FT  Data Scientist   160000
# 35        2021               MI              FT  Data Scientist    52000
# 37        2021               MI              FT  Data Scientist    69600
# 43        2021               SE              FT  Data Scientist   165000
# 44        2021               EN              FT  Data Scientist    90000
# 50        2021               EN              FT  Data Scientist    58000
# 52        2022               MI              FT  Data Scientist   130000
# 56        2022               SE              FT  Data Scientist   165220
# 81        2022               MI              FT  Data Scientist  2400000
# 85        2022               MI              FT  Data Scientist   140000
# 86        2022               MI              FT  Data Scientist    70000
# 87        2022               SE              FT  Data Scientist   185100
# 91        2022               MI              FT  Data Scientist   150000
# 93        2022               EN              FT  Data Scientist    40000
# 97        2022               MI              FT  Data Scientist    88000
# 104       2022               SE              FT  Data Scientist   230000
#
#     salary_currency employee_residence  remote_ratio company_location  \
# 6               EUR                 GR           100               US
# 8               USD                 PH           100               US
# 11              USD                 US            50               US
# 13              EUR                 IT            50               IT
# 15              EUR                 FR            50               FR
# 26              USD                 US             0               US
# 28              SGD                 SG           100               IL
# 35              EUR                 DE            50               AT
# 37              BRL                 BR             0               BR
# 43              USD                 US           100               US
# 44              USD                 US           100               US
# 50              USD                 US            50               US
# 52              USD                 US             0               US
# 56              USD                 US           100               US
# 81              INR                 IN           100               IN
# 85              GBP                 GB             0               GB
# 86              GBP                 GB             0               GB
# 87              USD                 US           100               US
# 91              PLN                 PL           100               PL
# 93              USD                 JP           100               MY
# 97              CAD                 CA           100               CA
# 104             USD                 US           100               US
#
#     company_size
# 6              L
# 8              S
# 11             L
# 13             S
# 15             S
# 26             S
# 28             M
# 35             M
# 37             S
# 43             L
# 44             S
# 50             L
# 52             M
# 56             M
# 81             L
# 85             M
# 86             M
# 87             M
# 91             L
# 93             L
# 97             M
# 104            M

# %%
test[test.employee_residence == 'IN']
# Out:
#     work_year experience_level employment_type                  job_title  \
# 4        2020               MI              FT       Product Data Analyst
# 24       2021               EN              FT  Machine Learning Engineer
# 41       2021               EN              FT          Big Data Engineer
# 80       2022               MI              FT      Business Data Analyst
# 81       2022               MI              FT             Data Scientist
#
#      salary salary_currency employee_residence  remote_ratio company_location  \
# 4    450000             INR                 IN           100               IN
# 24    20000             USD                 IN           100               IN
# 41  1200000             INR                 IN           100               IN
# 80  1400000             INR                 IN           100               IN
# 81  2400000             INR                 IN           100               IN
#
#    company_size
# 4             L
# 24            S
# 41            L
# 80            M
# 81            L

# %%
salaries[salaries.employee_residence == 'IN'].head()
# Out:
#     work_year experience_level employment_type                      job_title  \
# 18       2021               EN              FT                  Data Engineer
# 38       2021               EN              FT                   AI Scientist
# 62       2021               MI              PT  3D Computer Vision Researcher
# 85       2021               EX              FT                BI Data Analyst
# 98       2020               MI              FT                 Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 18  2250000             INR          30428                 IN           100
# 38  1335000             INR          18053                 IN           100
# 62   400000             INR           5409                 IN            50
# 85   150000             USD         150000                 IN           100
# 98  3000000             INR          40481                 IN             0
#
#    company_location company_size
# 18               IN            L
# 38               AS            S
# 62               IN            M
# 85               US            L
# 98               IN            L

# %% [markdown]
# # Limpieza de datos inconsistentes

# %%
salaries[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE')]


salaries.loc[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE') & (salaries.salary_in_usd < 120000) , "salary_in_usd"] = salaries[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE')]['salary_in_usd'].median()

salaries[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE')]
# Out:
#      work_year experience_level employment_type      job_title  salary  \
# 0         2022               SE              FT  Data Engineer  140250
# 1         2022               SE              FT  Data Engineer  135000
# 11        2022               SE              FT  Data Engineer  110500
# 12        2022               SE              FT  Data Engineer  136994
# 15        2022               SE              FT  Data Engineer  175000
# 22        2022               SE              FT  Data Engineer  154000
# 26        2022               SE              FT  Data Engineer  132320
# 54        2022               SE              FT  Data Engineer  165400
# 80        2021               SE              FT  Data Engineer  150000
# 87        2022               SE              FT  Data Engineer  183600
# 94        2022               SE              FT  Data Engineer  181940
# 99        2022               SE              FT  Data Engineer  126000
# 135       2022               SE              FT  Data Engineer  160080
# 152       2022               SE              FT  Data Engineer  130000
# 154       2022               SE              FT  Data Engineer  132320
# 158       2022               SE              FT  Data Engineer  154600
# 169       2022               SE              FT  Data Engineer  130000
# 170       2022               SE              FT  Data Engineer  160000
# 181       2021               SE              FT  Data Engineer  150000
# 182       2022               SE              FT  Data Engineer   54000
# 189       2022               SE              FT  Data Engineer  209100
# 210       2022               SE              FT  Data Engineer   80000
# 217       2022               SE              FT  Data Engineer   93700
# 225       2022               SE              FT  Data Engineer  209100
# 228       2022               SE              FT  Data Engineer  220110
# 247       2022               SE              FT  Data Engineer  108800
# 265       2022               SE              FT  Data Engineer  220110
# 270       2022               SE              FT  Data Engineer  165400
# 275       2022               SE              FT  Data Engineer  155000
# 277       2022               SE              FT  Data Engineer  155000
# 285       2022               SE              FT  Data Engineer   70500
# 307       2022               SE              FT  Data Engineer  160080
# 315       2022               SE              FT  Data Engineer  128875
# 327       2021               SE              FT  Data Engineer  165000
# 360       2022               SE              FT  Data Engineer  100800
# 361       2022               SE              FT  Data Engineer  113000
# 369       2022               SE              FT  Data Engineer  101570
# 395       2022               SE              FT  Data Engineer  160000
# 397       2022               SE              FT  Data Engineer  145000
# 399       2022               SE              FT  Data Engineer  115000
# 405       2022               SE              FT  Data Engineer  200100
# 406       2022               SE              FT  Data Engineer  100000
# 410       2022               SE              FT  Data Engineer  160000
# 412       2022               SE              FT  Data Engineer  105000
# 442       2021               SE              FT  Data Engineer  115000
# 477       2022               SE              FT  Data Engineer   25000
# 493       2022               SE              FT  Data Engineer  180000
# 495       2022               SE              FT  Data Engineer  100000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0               USD         140250                 US           100
# 1               USD         135000                 US           100
# 11              USD         142625                 US           100
# 12              USD         136994                 US           100
# 15              USD         175000                 US           100
# 22              USD         154000                 US           100
# 26              USD         132320                 US             0
# 54              USD         165400                 US           100
# 80              USD         150000                 US           100
# 87              USD         183600                 US           100
# 94              USD         181940                 US             0
# 99              USD         126000                 US           100
# 135             USD         160080                 US           100
# 152             USD         130000                 US           100
# 154             USD         132320                 US           100
# 158             USD         154600                 US           100
# 169             USD         130000                 US           100
# 170             USD         160000                 US             0
# 181             USD         150000                 US           100
# 182             USD         142625                 US             0
# 189             USD         209100                 US           100
# 210             USD         142625                 US           100
# 217             USD         142625                 US           100
# 225             USD         209100                 US           100
# 228             USD         220110                 US           100
# 247             USD         142625                 US             0
# 265             USD         220110                 US             0
# 270             USD         165400                 US           100
# 275             USD         155000                 US           100
# 277             USD         155000                 US           100
# 285             USD         142625                 US             0
# 307             USD         160080                 US             0
# 315             USD         128875                 US           100
# 327             USD         165000                 US             0
# 360             USD         142625                 US           100
# 361             USD         142625                 US             0
# 369             USD         142625                 US           100
# 395             USD         160000                 US           100
# 397             USD         145000                 US           100
# 399             USD         142625                 US           100
# 405             USD         200100                 US           100
# 406             USD         142625                 US           100
# 410             USD         160000                 US           100
# 412             USD         142625                 US           100
# 442             USD         142625                 US           100
# 477             USD         142625                 US           100
# 493             USD         180000                 US           100
# 495             USD         142625                 US           100
#
#     company_location company_size
# 0                 US            M
# 1                 US            M
# 11                US            M
# 12                US            M
# 15                US            M
# 22                US            M
# 26                US            M
# 54                US            M
# 80                US            L
# 87                US            L
# 94                US            M
# 99                US            M
# 135               US            M
# 152               US            M
# 154               US            M
# 158               US            L
# 169               US            M
# 170               US            L
# 181               US            M
# 182               US            M
# 189               US            L
# 210               US            M
# 217               US            M
# 225               US            L
# 228               US            M
# 247               US            M
# 265               US            M
# 270               US            M
# 275               US            M
# 277               US            M
# 285               US            M
# 307               US            M
# 315               US            M
# 327               US            M
# 360               US            L
# 361               US            L
# 369               US            M
# 395               US            M
# 397               US            M
# 399               US            M
# 405               US            M
# 406               US            M
# 410               US            M
# 412               US            M
# 442               US            S
# 477               US            M
# 493               US            M
# 495               US            M

# %%
muestra.head()
# Out:
#    id  salary_in_usd
# 0   0          70377
# 1   1          85839
# 2   2          63613
# 3   3          88561
# 4   4          37621

# %%
salaries.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# salaries = salaries.drop(['work_year', 'experience_level', 'employment_type', 'job_title', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'], axis = 1)

# %% [markdown]
# test = test.drop(['work_year', 'experience_level', 'employment_type', 'job_title', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'], axis = 1)

# %% [markdown]
# #Dropeando columnas de salarios en divisas
#
# X = salaries.drop(['salary','salary_currency','salary_in_usd'], axis=1)
#
# from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
# cols_label = ['work_year', 'experience_level', 'employment_type', 'job_title', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size']
# for i in cols_label:
#     X[i]=LabelEncoder().fit_transform(X[i])
#
# X.head()
#
#
# #X=pd.get_dummies(X, columns=['salary_currency'])#, drop_first=True)
#
# y = salaries.salary_in_usd
#
#
#
# X.head()

# %%
# Sin Dropear columnas de salarios en divisa

X = salaries.drop(['salary', 'salary_currency','salary_in_usd'], axis=1)
X_t = test.copy()
X_t = X_t.drop(['salary', 'salary_currency'], axis = 1)


concat = pd.concat([X, X_t], ignore_index=True)

concat
# Out:
#      work_year experience_level employment_type        job_title  \
# 0         2022               SE              FT    Data Engineer
# 1         2022               SE              FT    Data Engineer
# 2         2021               MI              FT  BI Data Analyst
# 3         2021               MI              CT      ML Engineer
# 4         2021               MI              FT    Data Engineer
# ..         ...              ...             ...              ...
# 602       2022               SE              FT     Data Analyst
# 603       2022               SE              FT   Data Architect
# 604       2022               SE              FT   Data Scientist
# 605       2022               EN              FT     Data Analyst
# 606       2022               SE              FT     Data Analyst
#
#     employee_residence  remote_ratio company_location company_size
# 0                   US           100               US            M
# 1                   US           100               US            M
# 2                   US           100               US            M
# 3                   US           100               US            L
# 4                   RO             0               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US           100               US            M
# 605                 CA             0               CA            M
# 606                 US             0               US            M
#
# [607 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
cols_label = ['work_year', 'experience_level', 'employment_type', 'job_title',
         'employee_residence',
       'remote_ratio', 'company_location', 'company_size']
for i in cols_label:
    concat[i]=LabelEncoder().fit_transform(concat[i])
    



#X=pd.get_dummies(X, columns=['salary_currency'])#, drop_first=True)

y = salaries.salary_in_usd



concat.head()
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0          2                 3                2         17
# 1          2                 3                2         17
# 2          1                 2                2          5
# 3          1                 2                0         36
# 4          1                 2                2         17
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  55             2                48             1
# 1                  55             2                48             1
# 2                  55             2                48             1
# 3                  55             2                48             0
# 4                  47             0                48             0

# %%
X = concat[0:500]

X_t = concat[500:]

X_t.head()
# Out:
#      work_year  experience_level  employment_type  job_title  \
# 500          0                 3                2         41
# 501          0                 2                2         32
# 502          0                 2                2         12
# 503          0                 2                2         38
# 504          0                 2                2         47
#
#      employee_residence  remote_ratio  company_location  company_size
# 500                  32             0                29             2
# 501                  55             2                48             0
# 502                  55             2                48             0
# 503                  11             0                 9             1
# 504                  27             2                25             0

# %%
test.head(20)
# Out:
#     work_year experience_level employment_type  \
# 0        2020               SE              FT
# 1        2020               MI              FT
# 2        2020               MI              FT
# 3        2020               MI              FT
# 4        2020               MI              FT
# 5        2020               SE              FT
# 6        2020               SE              FT
# 7        2020               MI              FT
# 8        2020               MI              FT
# 9        2020               SE              FT
# 10       2020               EN              FT
# 11       2020               SE              FT
# 12       2020               MI              FT
# 13       2020               EN              PT
# 14       2020               SE              FT
# 15       2020               MI              FT
# 16       2021               SE              FT
# 17       2021               MI              FT
# 18       2021               EN              FT
# 19       2021               MI              FT
#
#                             job_title  salary salary_currency  \
# 0          Machine Learning Scientist  260000             USD
# 1                   Lead Data Analyst   87000             USD
# 2                        Data Analyst   85000             USD
# 3           Machine Learning Engineer  299000             CNY
# 4                Product Data Analyst  450000             INR
# 5                       Data Engineer  720000             MXN
# 6                      Data Scientist   60000             EUR
# 7                        Data Analyst   41000             EUR
# 8                      Data Scientist   45760             USD
# 9                       Data Engineer  188000             USD
# 10                       AI Scientist  300000             DKK
# 11                     Data Scientist  120000             USD
# 12                      Data Engineer  130800             USD
# 13                     Data Scientist   19000             EUR
# 14          Machine Learning Engineer   40000             EUR
# 15                     Data Scientist   37000             EUR
# 16            Data Analytics Engineer   67000             EUR
# 17            Data Analytics Engineer  110000             USD
# 18            Data Science Consultant   65000             EUR
# 19  Computer Vision Software Engineer   81000             EUR
#
#    employee_residence  remote_ratio company_location company_size
# 0                  JP             0               JP            S
# 1                  US           100               US            L
# 2                  US           100               US            L
# 3                  CN             0               CN            M
# 4                  IN           100               IN            L
# 5                  MX             0               MX            S
# 6                  GR           100               US            L
# 7                  FR            50               FR            L
# 8                  PH           100               US            S
# 9                  US           100               US            L
# 10                 DK            50               DK            S
# 11                 US            50               US            L
# 12                 ES           100               US            M
# 13                 IT            50               IT            S
# 14                 HR           100               HR            S
# 15                 FR            50               FR            S
# 16                 DE           100               DE            L
# 17                 US           100               US            L
# 18                 DE           100               DE            S
# 19                 DE           100               US            S

# %%
salaries.head(10)
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2022               SE              FT               Data Engineer
# 1       2022               SE              FT               Data Engineer
# 2       2021               MI              FT             BI Data Analyst
# 3       2021               MI              CT                 ML Engineer
# 4       2021               MI              FT               Data Engineer
# 5       2022               MI              FT  Machine Learning Scientist
# 6       2020               EN              FT              Data Scientist
# 7       2021               EN              FT              Data Scientist
# 8       2022               MI              FT               Data Engineer
# 9       2021               EN              FT                Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  140250             USD         140250                 US           100
# 1  135000             USD         135000                 US           100
# 2  100000             USD         100000                 US           100
# 3  270000             USD         270000                 US           100
# 4   22000             EUR          26005                 RO             0
# 5  153000             USD         153000                 US            50
# 6   45000             EUR          51321                 FR             0
# 7   42000             EUR          49646                 FR            50
# 8   70000             EUR          76940                 GR           100
# 9   50000             EUR          59102                 FR            50
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L
# 5               US            M
# 6               FR            S
# 7               FR            M
# 8               GR            M
# 9               FR            M

# %%
X.head(10)
# Out:
#    work_year  experience_level  employment_type  job_title  \
# 0          2                 3                2         17
# 1          2                 3                2         17
# 2          1                 2                2          5
# 3          1                 2                0         36
# 4          1                 2                2         17
# 5          2                 2                2         41
# 6          0                 0                2         22
# 7          1                 0                2         22
# 8          2                 2                2         17
# 9          1                 0                2         12
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  55             2                48             1
# 1                  55             2                48             1
# 2                  55             2                48             1
# 3                  55             2                48             0
# 4                  47             0                48             0
# 5                  55             1                48             1
# 6                  19             0                17             2
# 7                  19             1                17             1
# 8                  21             2                19             1
# 9                  19             1                17             1

# %% [markdown]
# # Solo columnas de divisa y usd
#
# X = salaries.drop('salary_in_usd', axis=1)
#
# from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
# cols_label = ['salary_currency']
# for i in cols_label:
#     X[i]=LabelEncoder().fit_transform(X[i])
#
# X.head()
#
#
# #X=pd.get_dummies(X, columns=['salary_currency'])#, drop_first=True)
#
# y = salaries.salary_in_usd
#
#
#
# X.head()

# %%
from sklearn.model_selection import train_test_split

# Your code here:
y.shape
# Out:
# (500,)

# %%
X_train, X_test, y_train, y_test = tts(X, y, train_size=0.80, test_size=0.20)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 8), (100, 8), (400,), (100,))

# %%
from sklearn.metrics import mean_squared_error as mse 
from sklearn.linear_model import LinearRegression as LinReg

linreg=LinReg()   # Inicializar modelo linreg

linreg.fit(X_train, y_train)  #

y_pred_test=linreg.predict(X_test)
y_pred_train=linreg.predict(X_train)

# %%
X_train
# Out:
#      work_year  experience_level  employment_type  job_title  \
# 459          0                 0                0          8
# 462          1                 2                2         48
# 268          1                 0                2         22
# 145          2                 0                2         22
# 70           1                 3                2          1
# ..         ...               ...              ...        ...
# 259          0                 3                2          7
# 473          1                 0                2         38
# 207          1                 3                2         17
# 202          2                 2                2         17
# 461          1                 3                2         18
#
#      employee_residence  remote_ratio  company_location  company_size
# 459                  55             2                48             0
# 462                   8             2                 6             1
# 268                  27             1                25             0
# 145                   3             1                 3             1
# 70                   18             2                16             0
# ..                  ...           ...               ...           ...
# 259                  44             2                18             2
# 473                  55             1                48             2
# 207                  20             1                18             0
# 202                  20             2                18             1
# 461                  55             0                48             0
#
# [400 rows x 8 columns]

# %%
import lazypredict

# %% [markdown]
# # Lazypredict
#
#
#
# from lazypredict.Supervised import LazyClassifier
# from sklearn.datasets import load_breast_cancer
# from sklearn.model_selection import train_test_split
#
#
#
# #X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.5,random_state =123)
#
# clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
# models,predictions = clf.fit(X_train, X_test, y_train, y_test)
#
# print(models)

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np


'''
offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]
'''
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 42/42 [00:03<00:00, 12.98it/s]
#                                Adjusted R-Squared  R-Squared       RMSE  \
# Model
# HistGradientBoostingRegressor                0.50       0.54   53926.67
# RandomForestRegressor                        0.47       0.52   55587.19
# LGBMRegressor                                0.47       0.51   55819.77
# GradientBoostingRegressor                    0.46       0.50   56181.93
# BaggingRegressor                             0.39       0.44   59786.43
# AdaBoostRegressor                            0.36       0.42   61049.28
# ExtraTreesRegressor                          0.35       0.40   61592.85
# KNeighborsRegressor                          0.29       0.35   64345.37
# XGBRegressor                                 0.26       0.32   65900.99
# LassoCV                                      0.23       0.29   67184.91
# LassoLars                                    0.23       0.29   67217.06
# RidgeCV                                      0.23       0.29   67217.17
# Ridge                                        0.23       0.29   67219.51
# Lasso                                        0.23       0.29   67220.38
# LinearRegression                             0.23       0.29   67220.59
# TransformedTargetRegressor                   0.23       0.29   67220.59
# Lars                                         0.23       0.29   67220.59
# LassoLarsIC                                  0.23       0.29   67220.59
# BayesianRidge                                0.23       0.29   67229.72
# SGDRegressor                                 0.23       0.29   67326.62
# LassoLarsCV                                  0.23       0.29   67362.06
# LarsCV                                       0.23       0.29   67362.06
# HuberRegressor                               0.22       0.28   67522.78
# PassiveAggressiveRegressor                   0.22       0.28   67641.41
# OrthogonalMatchingPursuitCV                  0.22       0.28   67759.08
# RANSACRegressor                              0.21       0.28   67810.21
# ElasticNet                                   0.21       0.27   67989.61
# DecisionTreeRegressor                        0.19       0.26   68775.44
# TweedieRegressor                             0.18       0.25   69203.51
# OrthogonalMatchingPursuit                    0.17       0.24   69678.80
# ExtraTreeRegressor                           0.16       0.23   69945.73
# PoissonRegressor                             0.16       0.23   70069.69
# GammaRegressor                               0.16       0.23   70078.20
# ElasticNetCV                                -0.07       0.02   79053.81
# DummyRegressor                              -0.10      -0.01   80347.74
# NuSVR                                       -0.12      -0.03   81089.70
# QuantileRegressor                           -0.14      -0.05   81872.21
# SVR                                         -0.15      -0.05   81893.35
# KernelRidge                                 -2.17      -1.92  136292.59
# LinearSVR                                   -2.61      -2.31  145316.01
# MLPRegressor                                -2.62      -2.33  145599.40
# GaussianProcessRegressor                  -641.08    -589.20 1939196.04
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        0.49
# RandomForestRegressor                0.20
# LGBMRegressor                        0.08
# GradientBoostingRegressor            0.07
# BaggingRegressor                     0.02
# AdaBoostRegressor                    0.03
# ExtraTreesRegressor                  0.16
# KNeighborsRegressor                  0.02
# XGBRegressor                         0.14
# LassoCV                              0.09
# LassoLars                            0.01
# RidgeCV                              0.01
# Ridge                                0.01
# Lasso                                0.01
# LinearRegression                     0.01
# TransformedTargetRegressor           0.01
# Lars                                 0.02
# LassoLarsIC                          0.01
# BayesianRidge                        0.01
# SGDRegressor                         0.01
# LassoLarsCV                          0.02
# LarsCV                               0.03
# HuberRegressor                       0.03
# PassiveAggressiveRegressor           0.04
# OrthogonalMatchingPursuitCV          0.01
# RANSACRegressor                      0.06
# ElasticNet                           0.01
# DecisionTreeRegressor                0.01
# TweedieRegressor                     0.01
# OrthogonalMatchingPursuit            0.01
# ExtraTreeRegressor                   0.01
# PoissonRegressor                     0.01
# GammaRegressor                       0.01
# ElasticNetCV                         0.07
# DummyRegressor                       0.01
# NuSVR                                0.02
# QuantileRegressor                    1.00
# SVR                                  0.03
# KernelRidge                          0.02
# LinearSVR                            0.01
# MLPRegressor                         0.36
# GaussianProcessRegressor             0.02

# %%
rfr = Rfr()

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rfr.predict(X_train)

# %%
y_pred = list(y_pred)

# %%
y_train = list(y_train)

# %%
Test = salaries.copy()

# %%
Test = pd.DataFrame()
Test['Train'] = y_train
Test['RFR'] = y_pred

# %%
Test
# Out:
#       Train       RFR
# 0    100000 103141.67
# 1     63810  68455.42
# 2     29751  31658.80
# 3     86703  79044.76
# 4     55000  62768.00
# ..      ...       ...
# 395  114047 107564.09
# 396   81000 119590.00
# 397   96282  86848.41
# 398  104702  79337.64
# 399  150000 158882.77
#
# [400 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE = mean_squared_error(y_train, y_pred)
MSE
# Out:
# 585355902.1001822

# %%
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 24194.129496639925

# %% [markdown]
# test = pd.DataFrame(y_train)
#
# test['pred'] = list(y_pred)
#
# test

# %% [markdown]
# # Now I train the model with 100% of data in salaries

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

regressor =  HistGradientBoostingRegressor()

# %%
regressor.fit(X, y)
# Out:
# HistGradientBoostingRegressor()

# %% [markdown]
# # randomforest
#
# test_result = rfr.predict(X_t)

# %%
# HistGradientBoostingRegressor

test_result = regressor.predict(X_t)

# %%
X_t
# Out:
#      work_year  experience_level  employment_type  job_title  \
# 500          0                 3                2         41
# 501          0                 2                2         32
# 502          0                 2                2         12
# 503          0                 2                2         38
# 504          0                 2                2         47
# ..         ...               ...              ...        ...
# 602          2                 3                2         12
# 603          2                 3                2         16
# 604          2                 3                2         22
# 605          2                 0                2         12
# 606          2                 3                2         12
#
#      employee_residence  remote_ratio  company_location  company_size
# 500                  32             0                29             2
# 501                  55             2                48             0
# 502                  55             2                48             0
# 503                  11             0                 9             1
# 504                  27             2                25             0
# ..                  ...           ...               ...           ...
# 602                  55             2                48             1
# 603                  55             2                48             1
# 604                  55             2                48             1
# 605                   8             0                 6             1
# 606                  55             0                48             1
#
# [107 rows x 8 columns]

# %%
test
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               SE              FT  Machine Learning Scientist
# 1         2020               MI              FT           Lead Data Analyst
# 2         2020               MI              FT                Data Analyst
# 3         2020               MI              FT   Machine Learning Engineer
# 4         2020               MI              FT        Product Data Analyst
# ..         ...              ...             ...                         ...
# 102       2022               SE              FT                Data Analyst
# 103       2022               SE              FT              Data Architect
# 104       2022               SE              FT              Data Scientist
# 105       2022               EN              FT                Data Analyst
# 106       2022               SE              FT                Data Analyst
#
#      salary salary_currency employee_residence  remote_ratio company_location  \
# 0    260000             USD                 JP             0               JP
# 1     87000             USD                 US           100               US
# 2     85000             USD                 US           100               US
# 3    299000             CNY                 CN             0               CN
# 4    450000             INR                 IN           100               IN
# ..      ...             ...                ...           ...              ...
# 102  170000             USD                 US           100               US
# 103  192564             USD                 US           100               US
# 104  230000             USD                 US           100               US
# 105   52000             USD                 CA             0               CA
# 106  129000             USD                 US             0               US
#
#     company_size
# 0              S
# 1              L
# 2              L
# 3              M
# 4              L
# ..           ...
# 102            M
# 103            M
# 104            M
# 105            M
# 106            M
#
# [107 rows x 10 columns]

# %%
X_t ['id'] = [i for i in range(107)]
X_t ['salary_in_usd'] = list(test_result)

# %%
X_t.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size', 'id', 'salary_in_usd'],
#       dtype='object')

# %%
X_t = X_t.drop(['work_year', 'experience_level', 'employment_type', 'job_title'
       , 'employee_residence', 'remote_ratio',
       'company_location', 'company_size'], axis = 1)

X_t
# Out:
#       id  salary_in_usd
# 500    0       91139.74
# 501    1      237331.68
# 502    2      131241.99
# 503    3       89977.12
# 504    4       80495.85
# ..   ...            ...
# 602  102      115005.51
# 603  103      172776.21
# 604  104      160643.55
# 605  105       57846.67
# 606  106      111952.17
#
# [107 rows x 2 columns]

# %%
X_t.to_csv(r'C:\Users\pombo\OneDrive\Escritorio\Ironhack\Labs\Day35Proy\w6-Kaggle-Competition-Machine-Learning\data\test.csv', sep=',', index=False)

# %%
salaries[(salaries.job_title == 'Lead Data Analyst')]
# Out:
#      work_year experience_level employment_type          job_title   salary  \
# 138       2021               MI              FT  Lead Data Analyst  1450000
# 144       2021               SE              FT  Lead Data Analyst   170000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 138             INR          19609                 IN           100
# 144             USD         170000                 US           100
#
#     company_location company_size
# 138               IN            L
# 144               US            L

# %%
salaries[(salaries.job_title == 'Data Analyst') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US')]['salary_in_usd'].describe().T
# Out:
# count       58.00
# mean    107828.19
# std      31070.41
# min      50000.00
# 25%      90080.00
# 50%     103550.00
# 75%     128281.25
# max     200000.00
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# salaries[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE')]
#
#
# salaries.loc[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE') & (salaries.salary_in_usd < 120000) , "salary_in_usd"] = salaries[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE')]['salary_in_usd'].median()
#
# salaries[(salaries.job_title == 'Data Engineer') & (salaries.company_location == 'US') & (salaries.employee_residence == 'US') & (salaries.experience_level == 'SE')]

# %%
test[(test.job_title == 'Data Engineer') & (test.company_location == 'US') & (test.employee_residence == 'US') & (test.experience_level == 'SE')]['salary'].mean()
# Out:
# 167946.66666666666

# %%
test[test.company_location == 'US'].shape
# Out:
# (59, 10)
